# %%
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
import scikeras
from sklearn.model_selection import train_test_split
from scikeras.wrappers import KerasRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# %%
df = pd.read_csv('data_model.csv', index_col = 0)
df.sample(5)
# Out:
#              T1           F1          F2          F3         F4          F5  \
# 672.0  1.790057  2090.151721  354.926997  136.056488  20.833855  298.220078
# 964.0  2.695937  1993.544328  402.032452  131.532947  25.275127  338.463813
# 785.0  0.547391  1931.739832  124.507732  121.151346  22.667522  277.948292
# 269.0  2.448142  1966.733899  431.352926  146.831715  23.084397  298.971092
# 604.0  3.578784  1862.679792  341.672132   75.068600  25.956842  312.790306
#
#                F6         T2           T3          F7         F9        F10
# 672.0    1.894093  73.613409  1661.499549  296.370696   9.057567  68.253199
# 964.0  819.961314  74.977723  2120.968913  311.066777   7.410758  50.568878
# 785.0  609.004377  76.072252  2486.698093  262.937031   6.555170  60.322365
# 269.0  218.383484  79.696606  2590.493514  200.006492   8.263046  47.560567
# 604.0    9.046203  73.006935  1399.118555  160.519027  10.264664  73.738350

# %%
#df_1 = df.drop(['F1', 'F4', 'F5', 'F6', 'T2', 'F7', 'F8', 'F10'], axis = 1)

# %%
ds = df.values
X = ds[:,1:12]
y = ds[:,0]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3,random_state = 42)

#res= clf._predict_proba_lr(X_test,Y_test)

X_train.shape
# Out:
# (655, 11)

# %% [markdown]
# 2. Разрабатываем базовую модель

# %% [markdown]
# Строим простую полносвязную нейронную сеть (feed forward neural network). Выходной слой с одним линейным нейроном — для задачи регрессии. Функция активации — RELU в промежуточном слое и отсутствует в выходном.

# %%
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, BatchNormalization, LeakyReLU, Activation, Dropout, LSTM
from keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
normalizer = tf.keras.layers.Normalization(axis=-1)

# %%
X_train_norm = normalizer.adapt(np.array(X_train))

# %%
X_train.shape
# Out:
# (655, 11)

# %%
model = Sequential([
    Dense(12, activation='relu', kernel_initializer='normal', input_dim = 11),
    Dense(12, activation='relu', kernel_initializer='normal'),
    Dense(6, activation='relu', kernel_initializer='normal'),
    Dense(1, kernel_initializer='normal'),
])

model.compile(optimizer='adam')

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 12)                144
#
#  dense_1 (Dense)             (None, 12)                156
#
#  dense_2 (Dense)             (None, 6)                 78
#
#  dense_3 (Dense)             (None, 1)                 7
#
# =================================================================
# Total params: 385
# Trainable params: 385
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='mse', metrics=['mae'])

# %%
# %%time
history = model.fit(
    X_train,
    y_train,
    batch_size = 64,
    epochs=50,
    verbose=1,
    validation_split = 0.2
    )
# Out:
# Epoch 1/50
# 9/9 [==============================] - 1s 39ms/step - loss: 8.8965 - mae: 2.8381 - val_loss: 7.6580 - val_mae: 2.6255
# Epoch 2/50
# 9/9 [==============================] - 0s 8ms/step - loss: 6.3919 - mae: 2.3506 - val_loss: 4.0804 - val_mae: 1.8264
# Epoch 3/50
# 9/9 [==============================] - 0s 7ms/step - loss: 2.5135 - mae: 1.3247 - val_loss: 0.8740 - val_mae: 0.7525
# Epoch 4/50
# 9/9 [==============================] - 0s 6ms/step - loss: 1.3821 - mae: 0.9612 - val_loss: 1.2650 - val_mae: 0.8974
# Epoch 5/50
# 9/9 [==============================] - 0s 6ms/step - loss: 1.0088 - mae: 0.8140 - val_loss: 0.9520 - val_mae: 0.7890
# Epoch 6/50
# 9/9 [==============================] - 0s 6ms/step - loss: 1.0389 - mae: 0.8195 - val_loss: 0.8870 - val_mae: 0.7563
# Epoch 7/50
# 9/9 [==============================] - 0s 7ms/step - loss: 0.9391 - mae: 0.7830 - val_loss: 0.8854 - val_mae: 0.7606
# Epoch 8/50
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9307 - mae: 0.7791 - val_loss: 0.8652 - val_mae: 0.7497
# Epoch 9/50
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9302 - mae: 0.7779 - val_loss: 0.8611 - val_mae: 0.7471
# Epoch 10/50
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9240 - mae: 0.7772 - val_loss: 0.8738 - val_mae: 0.7543
# Epoch 11/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9130 - mae: 0.7729 - val_loss: 0.8573 - val_mae: 0.7455
# Epoch 12/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9231 - mae: 0.7750 - val_loss: 0.8552 - val_mae: 0.7448
# Epoch 13/50
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9072 - mae: 0.7686 - val_loss: 0.8669 - val_mae: 0.7501
# Epoch 14/50
# 9/9 [==============================] - 0s 6ms/step - loss: 0.9057 - mae: 0.7707 - val_loss: 0.8560 - val_mae: 0.7458
# Epoch 15/50
# 9/9 [==============================] - 0s 6ms/step - loss: 0.8983 - mae: 0.7666 - val_loss: 0.8539 - val_mae: 0.7448
# Epoch 16/50
# 9/9 [==============================] - 0s 6ms/step - loss: 0.8961 - mae: 0.7657 - val_loss: 0.8521 - val_mae: 0.7438
# Epoch 17/50
# 9/9 [==============================] - 0s 6ms/step - loss: 0.8915 - mae: 0.7644 - val_loss: 0.8539 - val_mae: 0.7443
# Epoch 18/50
# 9/9 [==============================] - 0s 6ms/step - loss: 0.8862 - mae: 0.7615 - val_loss: 0.8462 - val_mae: 0.7418
# Epoch 19/50
# 9/9 [==============================] - 0s 6ms/step - loss: 0.8850 - mae: 0.7611 - val_loss: 0.8494 - val_mae: 0.7428
# Epoch 20/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.8805 - mae: 0.7594 - val_loss: 0.8477 - val_mae: 0.7421
# Epoch 21/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.8807 - mae: 0.7586 - val_loss: 0.8426 - val_mae: 0.7401
# Epoch 22/50
# 9/9 [==============================] - 0s 7ms/step - loss: 0.8779 - mae: 0.7573 - val_loss: 0.8493 - val_mae: 0.7420
# Epoch 23/50
# 9/9 [==============================] - 0s 6ms/step - loss: 0.8812 - mae: 0.7598 - val_loss: 0.8417 - val_mae: 0.7396
# Epoch 24/50
# 9/9 [==============================] - 0s 6ms/step - loss: 0.8854 - mae: 0.7620 - val_loss: 0.8375 - val_mae: 0.7377
# Epoch 25/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.8759 - mae: 0.7560 - val_loss: 0.8454 - val_mae: 0.7396
# Epoch 26/50
# 9/9 [==============================] - 0s 6ms/step - loss: 0.8658 - mae: 0.7534 - val_loss: 0.8349 - val_mae: 0.7362
# Epoch 27/50
# 9/9 [==============================] - 0s 6ms/step - loss: 0.8779 - mae: 0.7594 - val_loss: 0.8340 - val_mae: 0.7355
# Epoch 28/50
# 9/9 [==============================] - 0s 6ms/step - loss: 0.8739 - mae: 0.7559 - val_loss: 0.8305 - val_mae: 0.7330
# Epoch 29/50
# 9/9 [==============================] - 0s 6ms/step - loss: 0.8818 - mae: 0.7586 - val_loss: 0.8362 - val_mae: 0.7345
# Epoch 30/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.8647 - mae: 0.7522 - val_loss: 0.8276 - val_mae: 0.7321
# Epoch 31/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.8728 - mae: 0.7554 - val_loss: 0.8344 - val_mae: 0.7334
# Epoch 32/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.8505 - mae: 0.7464 - val_loss: 0.8255 - val_mae: 0.7298
# Epoch 33/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.8595 - mae: 0.7503 - val_loss: 0.8344 - val_mae: 0.7325
# Epoch 34/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.8780 - mae: 0.7591 - val_loss: 0.8263 - val_mae: 0.7294
# Epoch 35/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.8567 - mae: 0.7489 - val_loss: 0.8247 - val_mae: 0.7282
# Epoch 36/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.8504 - mae: 0.7455 - val_loss: 0.8276 - val_mae: 0.7286
# Epoch 37/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.8461 - mae: 0.7433 - val_loss: 0.8261 - val_mae: 0.7277
# Epoch 38/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.8452 - mae: 0.7433 - val_loss: 0.8231 - val_mae: 0.7261
# Epoch 39/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.8418 - mae: 0.7424 - val_loss: 0.8258 - val_mae: 0.7264
# Epoch 40/50
# 9/9 [==============================] - 0s 6ms/step - loss: 0.8491 - mae: 0.7447 - val_loss: 0.8220 - val_mae: 0.7247
# Epoch 41/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.8442 - mae: 0.7437 - val_loss: 0.8250 - val_mae: 0.7259
# Epoch 42/50
# 9/9 [==============================] - 0s 8ms/step - loss: 0.8608 - mae: 0.7489 - val_loss: 0.8181 - val_mae: 0.7226
# Epoch 43/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.8425 - mae: 0.7407 - val_loss: 0.8158 - val_mae: 0.7214
# Epoch 44/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.8371 - mae: 0.7404 - val_loss: 0.8204 - val_mae: 0.7228
# Epoch 45/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.8320 - mae: 0.7377 - val_loss: 0.8137 - val_mae: 0.7195
# Epoch 46/50
# 9/9 [==============================] - 0s 10ms/step - loss: 0.8343 - mae: 0.7399 - val_loss: 0.8187 - val_mae: 0.7210
# Epoch 47/50
# 9/9 [==============================] - 0s 11ms/step - loss: 0.8343 - mae: 0.7385 - val_loss: 0.8226 - val_mae: 0.7230
# Epoch 48/50
# 9/9 [==============================] - 0s 9ms/step - loss: 0.8388 - mae: 0.7424 - val_loss: 0.8128 - val_mae: 0.7173
# Epoch 49/50
# 9/9 [==============================] - 0s 6ms/step - loss: 0.8327 - mae: 0.7387 - val_loss: 0.8104 - val_mae: 0.7159
# Epoch 50/50
# 9/9 [==============================] - 0s 6ms/step - loss: 0.8367 - mae: 0.7403 - val_loss: 0.8134 - val_mae: 0.7177
# Wall time: 4.35 s

# %%
mse, mae = model.evaluate(X_test, y_test, verbose=0)

# %%
print("Средняя абсолютная ошибка (ед.):", mae)
# Out:
# Средняя абсолютная ошибка (ед.): 0.7154476642608643

# %%
pred = model.predict(X_test)
print("Предсказанное соотношение:", pred[1][0], ", правильное соотношение:", y_test[1])
# Out:
# Предсказанное соотношение: 3.0653412 , правильное соотношение: 1.94002141130966

# %%
# Предсказание vs правильный ответ
for i in range(len(pred)):
  print("Сеть сказала: ", np.round(pred[i],2), ", а верный ответ: ", np.round(y_test[i],2), ", разница: ", np.round(pred[i] - y_test[i],2))
# Out:
# Сеть сказала:  [2.82] , а верный ответ:  2.87 , разница:  [-0.06]
# Сеть сказала:  [3.07] , а верный ответ:  1.94 , разница:  [1.13]
# Сеть сказала:  [3.17] , а верный ответ:  1.72 , разница:  [1.45]
# Сеть сказала:  [2.97] , а верный ответ:  4.6 , разница:  [-1.64]
# Сеть сказала:  [2.81] , а верный ответ:  3.46 , разница:  [-0.65]
# Сеть сказала:  [3.] , а верный ответ:  2.68 , разница:  [0.31]
# Сеть сказала:  [2.84] , а верный ответ:  1.52 , разница:  [1.32]
# Сеть сказала:  [2.97] , а верный ответ:  3.55 , разница:  [-0.58]
# Сеть сказала:  [2.75] , а верный ответ:  2.57 , разница:  [0.18]
# Сеть сказала:  [3.01] , а верный ответ:  2.38 , разница:  [0.63]
# Сеть сказала:  [3.1] , а верный ответ:  2.05 , разница:  [1.05]
# Сеть сказала:  [3.07] , а верный ответ:  2.45 , разница:  [0.62]
# Сеть сказала:  [3.03] , а верный ответ:  3.41 , разница:  [-0.37]
# Сеть сказала:  [3.03] , а верный ответ:  2.51 , разница:  [0.53]
# Сеть сказала:  [2.82] , а верный ответ:  3.48 , разница:  [-0.66]
# Сеть сказала:  [2.76] , а верный ответ:  3.1 , разница:  [-0.34]
# Сеть сказала:  [2.85] , а верный ответ:  2.41 , разница:  [0.44]
# Сеть сказала:  [2.82] , а верный ответ:  2.17 , разница:  [0.65]
# Сеть сказала:  [2.98] , а верный ответ:  1.55 , разница:  [1.43]
# Сеть сказала:  [3.04] , а верный ответ:  2.79 , разница:  [0.25]
# Сеть сказала:  [2.85] , а верный ответ:  2.2 , разница:  [0.65]
# Сеть сказала:  [2.83] , а верный ответ:  4.08 , разница:  [-1.25]
# Сеть сказала:  [2.9] , а верный ответ:  3.71 , разница:  [-0.81]
# Сеть сказала:  [2.92] , а верный ответ:  2.98 , разница:  [-0.06]
# Сеть сказала:  [3.01] , а верный ответ:  2.54 , разница:  [0.46]
# Сеть сказала:  [3.02] , а верный ответ:  4.67 , разница:  [-1.65]
# Сеть сказала:  [3.17] , а верный ответ:  1.84 , разница:  [1.34]
# Сеть сказала:  [2.79] , а верный ответ:  3.3 , разница:  [-0.51]
# Сеть сказала:  [3.] , а верный ответ:  4.31 , разница:  [-1.31]
# Сеть сказала:  [2.92] , а верный ответ:  3.08 , разница:  [-0.16]
# Сеть сказала:  [3.09] , а верный ответ:  2.61 , разница:  [0.48]
# Сеть сказала:  [2.85] , а верный ответ:  2.54 , разница:  [0.31]
# Сеть сказала:  [2.84] , а верный ответ:  1.19 , разница:  [1.64]
# Сеть сказала:  [2.85] , а верный ответ:  2.04 , разница:  [0.81]
# Сеть сказала:  [2.97] , а верный ответ:  2.98 , разница:  [-0.01]
# Сеть сказала:  [2.95] , а верный ответ:  3.5 , разница:  [-0.55]
# Сеть сказала:  [2.92] , а верный ответ:  3.91 , разница:  [-0.99]
# Сеть сказала:  [2.84] , а верный ответ:  1.5 , разница:  [1.34]
# Сеть сказала:  [3.05] , а верный ответ:  3.75 , разница:  [-0.71]
# Сеть сказала:  [3.14] , а верный ответ:  3.95 , разница:  [-0.81]
# Сеть сказала:  [3.15] , а верный ответ:  2.68 , разница:  [0.46]
# Сеть сказала:  [3.22] , а верный ответ:  2.53 , разница:  [0.68]
# Сеть сказала:  [2.79] , а верный ответ:  3.02 , разница:  [-0.24]
# Сеть сказала:  [2.68] , а верный ответ:  1.72 , разница:  [0.97]
# Сеть сказала:  [3.] , а верный ответ:  2.15 , разница:  [0.85]
# Сеть сказала:  [2.85] , а верный ответ:  2.62 , разница:  [0.23]
# Сеть сказала:  [2.93] , а верный ответ:  3.43 , разница:  [-0.5]
# Сеть сказала:  [2.98] , а верный ответ:  3.04 , разница:  [-0.06]
# Сеть сказала:  [3.1] , а верный ответ:  4.36 , разница:  [-1.26]
# Сеть сказала:  [2.97] , а верный ответ:  2.66 , разница:  [0.31]
# Сеть сказала:  [2.86] , а верный ответ:  3.94 , разница:  [-1.08]
# Сеть сказала:  [3.16] , а верный ответ:  2.69 , разница:  [0.47]
# Сеть сказала:  [3.02] , а верный ответ:  3.36 , разница:  [-0.34]
# Сеть сказала:  [3.15] , а верный ответ:  2.48 , разница:  [0.68]
# Сеть сказала:  [3.03] , а верный ответ:  1.86 , разница:  [1.17]
# Сеть сказала:  [2.83] , а верный ответ:  3.31 , разница:  [-0.48]
# Сеть сказала:  [3.42] , а верный ответ:  5.3 , разница:  [-1.87]
# Сеть сказала:  [2.83] , а верный ответ:  2.42 , разница:  [0.42]
# Сеть сказала:  [3.1] , а верный ответ:  3.39 , разница:  [-0.29]
# Сеть сказала:  [3.18] , а верный ответ:  4.44 , разница:  [-1.26]
# Сеть сказала:  [2.94] , а верный ответ:  0.97 , разница:  [1.97]
# Сеть сказала:  [3.1] , а верный ответ:  3.04 , разница:  [0.06]
# Сеть сказала:  [2.86] , а верный ответ:  4.48 , разница:  [-1.62]
# Сеть сказала:  [3.06] , а верный ответ:  3.35 , разница:  [-0.29]
# Сеть сказала:  [2.95] , а верный ответ:  1.49 , разница:  [1.46]
# Сеть сказала:  [2.98] , а верный ответ:  2.92 , разница:  [0.06]
# Сеть сказала:  [3.] , а верный ответ:  3.58 , разница:  [-0.59]
# Сеть сказала:  [2.89] , а верный ответ:  1.75 , разница:  [1.14]
# Сеть сказала:  [3.15] , а верный ответ:  1.0 , разница:  [2.15]
# Сеть сказала:  [2.89] , а верный ответ:  4.02 , разница:  [-1.13]
# Сеть сказала:  [3.09] , а верный ответ:  2.47 , разница:  [0.62]
# Сеть сказала:  [3.02] , а верный ответ:  3.65 , разница:  [-0.63]
# Сеть сказала:  [2.93] , а верный ответ:  3.19 , разница:  [-0.26]
# Сеть сказала:  [3.01] , а верный ответ:  2.89 , разница:  [0.12]
# Сеть сказала:  [3.19] , а верный ответ:  2.83 , разница:  [0.36]
# Сеть сказала:  [2.87] , а верный ответ:  4.43 , разница:  [-1.56]
# Сеть сказала:  [3.11] , а верный ответ:  3.03 , разница:  [0.08]
# Сеть сказала:  [2.98] , а верный ответ:  2.13 , разница:  [0.85]
# Сеть сказала:  [2.9] , а верный ответ:  2.82 , разница:  [0.08]
# Сеть сказала:  [3.09] , а верный ответ:  2.01 , разница:  [1.08]
# Сеть сказала:  [2.97] , а верный ответ:  2.59 , разница:  [0.38]
# Сеть сказала:  [2.86] , а верный ответ:  2.07 , разница:  [0.79]
# Сеть сказала:  [2.86] , а верный ответ:  3.75 , разница:  [-0.89]
# Сеть сказала:  [2.75] , а верный ответ:  2.75 , разница:  [0.01]
# Сеть сказала:  [2.85] , а верный ответ:  1.94 , разница:  [0.91]
# Сеть сказала:  [2.92] , а верный ответ:  2.89 , разница:  [0.03]
# Сеть сказала:  [2.92] , а верный ответ:  1.54 , разница:  [1.37]
# Сеть сказала:  [3.05] , а верный ответ:  2.26 , разница:  [0.79]
# Сеть сказала:  [3.19] , а верный ответ:  4.23 , разница:  [-1.05]
# Сеть сказала:  [3.05] , а верный ответ:  2.71 , разница:  [0.34]
# Сеть сказала:  [3.18] , а верный ответ:  2.08 , разница:  [1.11]
# Сеть сказала:  [2.95] , а верный ответ:  3.35 , разница:  [-0.41]
# Сеть сказала:  [2.93] , а верный ответ:  2.7 , разница:  [0.24]
# Сеть сказала:  [3.26] , а верный ответ:  2.15 , разница:  [1.11]
# Сеть сказала:  [2.84] , а верный ответ:  4.53 , разница:  [-1.69]
# Сеть сказала:  [2.76] , а верный ответ:  1.71 , разница:  [1.06]
# Сеть сказала:  [3.07] , а верный ответ:  1.82 , разница:  [1.25]
# Сеть сказала:  [3.14] , а верный ответ:  1.8 , разница:  [1.34]
# Сеть сказала:  [2.9] , а верный ответ:  3.17 , разница:  [-0.28]
# Сеть сказала:  [3.05] , а верный ответ:  4.41 , разница:  [-1.36]
# Сеть сказала:  [2.88] , а верный ответ:  3.38 , разница:  [-0.5]
# Сеть сказала:  [3.03] , а верный ответ:  1.89 , разница:  [1.14]
# Сеть сказала:  [2.97] , а верный ответ:  2.0 , разница:  [0.96]
# Сеть сказала:  [3.24] , а верный ответ:  2.98 , разница:  [0.26]
# Сеть сказала:  [2.92] , а верный ответ:  2.66 , разница:  [0.26]
# Сеть сказала:  [2.78] , а верный ответ:  4.38 , разница:  [-1.6]
# Сеть сказала:  [3.11] , а верный ответ:  2.99 , разница:  [0.12]
# Сеть сказала:  [3.07] , а верный ответ:  2.76 , разница:  [0.31]
# Сеть сказала:  [2.84] , а верный ответ:  4.06 , разница:  [-1.22]
# Сеть сказала:  [2.8] , а верный ответ:  3.71 , разница:  [-0.91]
# Сеть сказала:  [2.79] , а верный ответ:  3.2 , разница:  [-0.4]
# Сеть сказала:  [3.13] , а верный ответ:  3.55 , разница:  [-0.42]
# Сеть сказала:  [2.94] , а верный ответ:  2.99 , разница:  [-0.05]
# Сеть сказала:  [3.27] , а верный ответ:  2.83 , разница:  [0.43]
# Сеть сказала:  [3.18] , а верный ответ:  3.76 , разница:  [-0.58]
# Сеть сказала:  [3.] , а верный ответ:  2.17 , разница:  [0.83]
# Сеть сказала:  [2.92] , а верный ответ:  2.2 , разница:  [0.72]
# Сеть сказала:  [3.14] , а верный ответ:  2.68 , разница:  [0.46]
# Сеть сказала:  [2.82] , а верный ответ:  2.33 , разница:  [0.49]
# Сеть сказала:  [3.01] , а верный ответ:  3.0 , разница:  [0.01]
# Сеть сказала:  [2.95] , а верный ответ:  2.27 , разница:  [0.68]
# Сеть сказала:  [2.72] , а верный ответ:  3.44 , разница:  [-0.72]
# Сеть сказала:  [2.95] , а верный ответ:  4.12 , разница:  [-1.17]
# Сеть сказала:  [2.94] , а верный ответ:  3.39 , разница:  [-0.45]
# Сеть сказала:  [2.93] , а верный ответ:  2.34 , разница:  [0.58]
# Сеть сказала:  [2.77] , а верный ответ:  1.83 , разница:  [0.94]
# Сеть сказала:  [3.12] , а верный ответ:  2.66 , разница:  [0.46]
# Сеть сказала:  [3.47] , а верный ответ:  2.2 , разница:  [1.27]
# Сеть сказала:  [2.99] , а верный ответ:  3.55 , разница:  [-0.56]
# Сеть сказала:  [3.09] , а верный ответ:  3.14 , разница:  [-0.04]
# Сеть сказала:  [2.82] , а верный ответ:  3.11 , разница:  [-0.29]
# Сеть сказала:  [3.] , а верный ответ:  2.12 , разница:  [0.88]
# Сеть сказала:  [2.97] , а верный ответ:  2.43 , разница:  [0.55]
# Сеть сказала:  [3.2] , а верный ответ:  2.91 , разница:  [0.29]
# Сеть сказала:  [2.9] , а верный ответ:  3.89 , разница:  [-0.99]
# Сеть сказала:  [3.] , а верный ответ:  3.27 , разница:  [-0.27]
# Сеть сказала:  [2.74] , а верный ответ:  2.02 , разница:  [0.72]
# Сеть сказала:  [2.89] , а верный ответ:  2.61 , разница:  [0.29]
# Сеть сказала:  [3.18] , а верный ответ:  4.34 , разница:  [-1.16]
# Сеть сказала:  [2.9] , а верный ответ:  2.9 , разница:  [-0.]
# Сеть сказала:  [2.72] , а верный ответ:  4.64 , разница:  [-1.92]
# Сеть сказала:  [2.99] , а верный ответ:  1.17 , разница:  [1.82]
# Сеть сказала:  [2.81] , а верный ответ:  2.56 , разница:  [0.25]
# Сеть сказала:  [3.12] , а верный ответ:  2.21 , разница:  [0.91]
# Сеть сказала:  [3.18] , а верный ответ:  2.77 , разница:  [0.41]
# Сеть сказала:  [2.69] , а верный ответ:  3.36 , разница:  [-0.66]
# Сеть сказала:  [2.91] , а верный ответ:  3.9 , разница:  [-0.99]
# Сеть сказала:  [2.69] , а верный ответ:  3.73 , разница:  [-1.03]
# Сеть сказала:  [2.87] , а верный ответ:  2.83 , разница:  [0.04]
# Сеть сказала:  [2.58] , а верный ответ:  3.36 , разница:  [-0.78]
# Сеть сказала:  [3.07] , а верный ответ:  3.36 , разница:  [-0.29]
# Сеть сказала:  [3.13] , а верный ответ:  2.75 , разница:  [0.38]
# Сеть сказала:  [2.85] , а верный ответ:  1.04 , разница:  [1.81]
# Сеть сказала:  [3.24] , а верный ответ:  1.83 , разница:  [1.41]
# Сеть сказала:  [3.12] , а верный ответ:  3.39 , разница:  [-0.27]
# Сеть сказала:  [3.09] , а верный ответ:  1.3 , разница:  [1.78]
# Сеть сказала:  [2.97] , а верный ответ:  2.11 , разница:  [0.87]
# Сеть сказала:  [2.98] , а верный ответ:  3.29 , разница:  [-0.31]
# Сеть сказала:  [3.04] , а верный ответ:  3.63 , разница:  [-0.59]
# Сеть сказала:  [3.04] , а верный ответ:  2.99 , разница:  [0.05]
# Сеть сказала:  [2.89] , а верный ответ:  3.11 , разница:  [-0.22]
# Сеть сказала:  [2.94] , а верный ответ:  3.65 , разница:  [-0.71]
# Сеть сказала:  [2.99] , а верный ответ:  3.58 , разница:  [-0.59]
# Сеть сказала:  [2.64] , а верный ответ:  2.69 , разница:  [-0.06]
# Сеть сказала:  [3.] , а верный ответ:  1.2 , разница:  [1.81]
# Сеть сказала:  [3.21] , а верный ответ:  2.76 , разница:  [0.45]
# Сеть сказала:  [3.22] , а верный ответ:  4.12 , разница:  [-0.9]
# Сеть сказала:  [3.04] , а верный ответ:  2.92 , разница:  [0.12]
# Сеть сказала:  [2.74] , а верный ответ:  2.42 , разница:  [0.32]
# Сеть сказала:  [3.06] , а верный ответ:  2.92 , разница:  [0.15]
# Сеть сказала:  [3.03] , а верный ответ:  3.75 , разница:  [-0.72]
# Сеть сказала:  [2.92] , а верный ответ:  1.88 , разница:  [1.04]
# Сеть сказала:  [3.1] , а верный ответ:  2.29 , разница:  [0.81]
# Сеть сказала:  [3.29] , а верный ответ:  3.05 , разница:  [0.24]
# Сеть сказала:  [2.91] , а верный ответ:  2.36 , разница:  [0.55]
# Сеть сказала:  [2.87] , а верный ответ:  2.22 , разница:  [0.65]
# Сеть сказала:  [3.14] , а верный ответ:  2.95 , разница:  [0.19]
# Сеть сказала:  [2.86] , а верный ответ:  2.39 , разница:  [0.48]
# Сеть сказала:  [3.4] , а верный ответ:  2.91 , разница:  [0.49]
# Сеть сказала:  [3.] , а верный ответ:  3.32 , разница:  [-0.32]
# Сеть сказала:  [2.95] , а верный ответ:  1.19 , разница:  [1.76]
# Сеть сказала:  [3.] , а верный ответ:  2.1 , разница:  [0.9]
# Сеть сказала:  [3.13] , а верный ответ:  1.74 , разница:  [1.39]
# Сеть сказала:  [3.14] , а верный ответ:  4.05 , разница:  [-0.91]
# Сеть сказала:  [3.17] , а верный ответ:  2.77 , разница:  [0.4]
# Сеть сказала:  [3.18] , а верный ответ:  2.5 , разница:  [0.68]
# Сеть сказала:  [3.15] , а верный ответ:  2.8 , разница:  [0.35]
# Сеть сказала:  [2.85] , а верный ответ:  3.84 , разница:  [-0.99]
# Сеть сказала:  [2.65] , а верный ответ:  2.56 , разница:  [0.09]
# Сеть сказала:  [2.77] , а верный ответ:  3.12 , разница:  [-0.35]
# Сеть сказала:  [2.81] , а верный ответ:  2.19 , разница:  [0.62]
# Сеть сказала:  [3.17] , а верный ответ:  3.65 , разница:  [-0.48]
# Сеть сказала:  [3.31] , а верный ответ:  2.73 , разница:  [0.58]
# Сеть сказала:  [2.79] , а верный ответ:  2.98 , разница:  [-0.18]
# Сеть сказала:  [2.95] , а верный ответ:  5.11 , разница:  [-2.16]
# Сеть сказала:  [2.9] , а верный ответ:  3.55 , разница:  [-0.65]
# Сеть сказала:  [2.87] , а верный ответ:  3.13 , разница:  [-0.27]
# Сеть сказала:  [2.84] , а верный ответ:  4.0 , разница:  [-1.16]
# Сеть сказала:  [2.98] , а верный ответ:  3.62 , разница:  [-0.64]
# Сеть сказала:  [3.] , а верный ответ:  2.16 , разница:  [0.84]
# Сеть сказала:  [3.03] , а верный ответ:  1.24 , разница:  [1.79]
# Сеть сказала:  [2.75] , а верный ответ:  2.71 , разница:  [0.04]
# Сеть сказала:  [2.79] , а верный ответ:  2.14 , разница:  [0.65]
# Сеть сказала:  [2.95] , а верный ответ:  1.6 , разница:  [1.35]
# Сеть сказала:  [3.05] , а верный ответ:  2.58 , разница:  [0.47]
# Сеть сказала:  [3.17] , а верный ответ:  3.17 , разница:  [0.]
# Сеть сказала:  [3.07] , а верный ответ:  2.78 , разница:  [0.29]
# Сеть сказала:  [2.93] , а верный ответ:  2.07 , разница:  [0.86]
# Сеть сказала:  [3.03] , а верный ответ:  1.72 , разница:  [1.31]
# Сеть сказала:  [3.08] , а верный ответ:  2.76 , разница:  [0.33]
# Сеть сказала:  [3.03] , а верный ответ:  2.87 , разница:  [0.16]
# Сеть сказала:  [3.11] , а верный ответ:  4.59 , разница:  [-1.49]
# Сеть сказала:  [2.95] , а верный ответ:  3.28 , разница:  [-0.32]
# Сеть сказала:  [2.93] , а верный ответ:  2.68 , разница:  [0.25]
# Сеть сказала:  [3.09] , а верный ответ:  2.8 , разница:  [0.29]
# Сеть сказала:  [3.12] , а верный ответ:  4.75 , разница:  [-1.63]
# Сеть сказала:  [2.89] , а верный ответ:  1.93 , разница:  [0.96]
# Сеть сказала:  [3.15] , а верный ответ:  2.9 , разница:  [0.25]
# Сеть сказала:  [2.94] , а верный ответ:  4.8 , разница:  [-1.86]
# Сеть сказала:  [3.14] , а верный ответ:  2.89 , разница:  [0.25]
# Сеть сказала:  [3.24] , а верный ответ:  2.53 , разница:  [0.71]
# Сеть сказала:  [3.08] , а верный ответ:  3.27 , разница:  [-0.19]
# Сеть сказала:  [2.92] , а верный ответ:  2.44 , разница:  [0.48]
# Сеть сказала:  [2.96] , а верный ответ:  2.36 , разница:  [0.6]
# Сеть сказала:  [3.1] , а верный ответ:  0.88 , разница:  [2.23]
# Сеть сказала:  [3.13] , а верный ответ:  3.05 , разница:  [0.07]
# Сеть сказала:  [2.93] , а верный ответ:  1.56 , разница:  [1.37]
# Сеть сказала:  [2.63] , а верный ответ:  2.93 , разница:  [-0.3]
# Сеть сказала:  [3.06] , а верный ответ:  3.32 , разница:  [-0.26]
# Сеть сказала:  [3.07] , а верный ответ:  2.86 , разница:  [0.21]
# Сеть сказала:  [2.97] , а верный ответ:  3.19 , разница:  [-0.22]
# Сеть сказала:  [3.11] , а верный ответ:  3.16 , разница:  [-0.05]
# Сеть сказала:  [3.25] , а верный ответ:  2.5 , разница:  [0.75]
# Сеть сказала:  [3.] , а верный ответ:  4.27 , разница:  [-1.26]
# Сеть сказала:  [2.82] , а верный ответ:  4.55 , разница:  [-1.72]
# Сеть сказала:  [2.97] , а верный ответ:  2.47 , разница:  [0.5]
# Сеть сказала:  [3.1] , а верный ответ:  3.51 , разница:  [-0.41]
# Сеть сказала:  [2.79] , а верный ответ:  1.6 , разница:  [1.19]
# Сеть сказала:  [3.01] , а верный ответ:  1.85 , разница:  [1.16]
# Сеть сказала:  [2.91] , а верный ответ:  2.88 , разница:  [0.04]
# Сеть сказала:  [3.16] , а верный ответ:  2.42 , разница:  [0.74]
# Сеть сказала:  [2.99] , а верный ответ:  2.56 , разница:  [0.42]
# Сеть сказала:  [3.03] , а верный ответ:  3.27 , разница:  [-0.25]
# Сеть сказала:  [3.04] , а верный ответ:  3.96 , разница:  [-0.91]
# Сеть сказала:  [3.13] , а верный ответ:  4.71 , разница:  [-1.57]
# Сеть сказала:  [2.68] , а верный ответ:  0.83 , разница:  [1.86]
# Сеть сказала:  [3.02] , а верный ответ:  4.25 , разница:  [-1.24]
# Сеть сказала:  [3.21] , а верный ответ:  1.54 , разница:  [1.67]
# Сеть сказала:  [3.21] , а верный ответ:  3.53 , разница:  [-0.32]
# Сеть сказала:  [3.11] , а верный ответ:  3.6 , разница:  [-0.5]
# Сеть сказала:  [3.19] , а верный ответ:  2.28 , разница:  [0.92]
# Сеть сказала:  [2.85] , а верный ответ:  3.12 , разница:  [-0.27]
# Сеть сказала:  [3.03] , а верный ответ:  3.79 , разница:  [-0.76]
# Сеть сказала:  [2.89] , а верный ответ:  3.62 , разница:  [-0.72]
# Сеть сказала:  [2.98] , а верный ответ:  2.05 , разница:  [0.93]
# Сеть сказала:  [2.72] , а верный ответ:  2.44 , разница:  [0.29]
# Сеть сказала:  [2.93] , а верный ответ:  3.24 , разница:  [-0.31]
# Сеть сказала:  [3.] , а верный ответ:  3.19 , разница:  [-0.19]
# Сеть сказала:  [3.09] , а верный ответ:  2.98 , разница:  [0.11]
# Сеть сказала:  [3.15] , а верный ответ:  4.27 , разница:  [-1.12]
# Сеть сказала:  [2.88] , а верный ответ:  3.49 , разница:  [-0.6]
# Сеть сказала:  [3.03] , а верный ответ:  2.82 , разница:  [0.21]
# Сеть сказала:  [3.19] , а верный ответ:  2.55 , разница:  [0.64]
# Сеть сказала:  [2.97] , а верный ответ:  3.81 , разница:  [-0.84]
# Сеть сказала:  [3.23] , а верный ответ:  4.24 , разница:  [-1.01]
# Сеть сказала:  [2.69] , а верный ответ:  1.26 , разница:  [1.43]
# Сеть сказала:  [3.08] , а верный ответ:  2.75 , разница:  [0.33]
# Сеть сказала:  [3.1] , а верный ответ:  3.89 , разница:  [-0.79]
# Сеть сказала:  [3.1] , а верный ответ:  4.07 , разница:  [-0.98]
# Сеть сказала:  [3.07] , а верный ответ:  2.97 , разница:  [0.1]
# Сеть сказала:  [3.1] , а верный ответ:  2.4 , разница:  [0.7]
# Сеть сказала:  [2.93] , а верный ответ:  2.52 , разница:  [0.41]
# Сеть сказала:  [2.99] , а верный ответ:  3.99 , разница:  [-1.]
# Сеть сказала:  [3.04] , а верный ответ:  1.69 , разница:  [1.35]
# Сеть сказала:  [3.05] , а верный ответ:  4.46 , разница:  [-1.4]
# Сеть сказала:  [2.79] , а верный ответ:  2.37 , разница:  [0.43]
# Сеть сказала:  [2.81] , а верный ответ:  3.07 , разница:  [-0.26]
# Сеть сказала:  [2.81] , а верный ответ:  2.65 , разница:  [0.16]
# Сеть сказала:  [3.09] , а верный ответ:  4.53 , разница:  [-1.44]
# Сеть сказала:  [3.19] , а верный ответ:  3.1 , разница:  [0.1]
# Сеть сказала:  [2.83] , а верный ответ:  3.26 , разница:  [-0.43]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Функция для построения графика потерь модели на тренировочной и тестовой выборках
def model_loss_plot(model_history):
    plt.figure(figsize=(10, 5))
    plt.plot(model_history.history['loss'])
    plt.plot(model_history.history['val_loss'])
    plt.title('График потерь модели', size=12)
    plt.ylabel('Средняя абсолютная ошибка', size=12)
    plt.xlabel('Эпоха', size=12)
    plt.legend(['loss', 'val_loss'], loc='best')
    plt.show()

# %%
#Функция для построения графика оригинального и предсказанного значения у
def actual_and_predicted_plot(original_y, predicted_y):    
    plt.figure(figsize=(15,5))
    plt.title('Тестовые и прогнозные значения', size=12)
    plt.plot(original_y, color='blue', label = 'Тестовые значения')
    plt.plot(predicted_y, color='red', label = 'Прогнозные значения')
    plt.legend(loc='best')
    plt.show()

# %%
#Функция для построения точечного графика оригинального и предсказанного значения у   
def actual_and_predicted_scatter(original_y, predicted_y):
    plt.figure(figsize=(10,5))
    plt.title('Рассеяние тестовых и прогнозных значений', size=15)
    plt.scatter(original_upr, predicted_upr)
    plt.xlabel('Тестовые значения', size=12)
    plt.ylabel('Прогнозные значения', size=12)
    plt.legend(loc='best')
    plt.show()

# %%
model_loss_plot(history)

# %%
pred = model.predict(np.array((X_test)))
original = y_test
predicted = pred

actual_and_predicted_plot(predicted, original)

# %%
# Разброс предсказаний может показать перекос, если есть
plt.scatter(y_test, pred) 
plt.xlabel('Правильные значение')
plt.ylabel('Предсказания')
plt.axis('equal')
plt.xlim(plt.xlim())
plt.ylim(plt.ylim())
plt.plot([-100, 100], [-100, 100])
plt.show()

# %%
plt.hist(pred)
# Out:
# (array([ 4., 13., 34., 52., 61., 59., 41., 13.,  1.,  3.]),
#  array([2.5759218, 2.6654704, 2.755019 , 2.8445675, 2.9341161, 3.0236647,
#         3.1132133, 3.202762 , 3.2923105, 3.381859 , 3.4714077],
#        dtype=float32),
#  <BarContainer object of 10 artists>)

# %%
model.save("divination_mlp_10")
# Out:
# INFO:tensorflow:Assets written to: divination_mlp_10\assets

# %%
mod = np.array(X_test)[0]

# %%
mod.shape
# Out:
# (11,)

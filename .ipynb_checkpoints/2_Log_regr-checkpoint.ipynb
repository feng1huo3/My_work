# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, StratifiedKFold, GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import precision_score, recall_score, auc, accuracy_score, roc_auc_score,f1_score,log_loss,\
classification_report, roc_curve

import warnings
warnings.filterwarnings("ignore");

RAND = 10

# %% [markdown]
# # Импорт данных

# %%
df = pd.read_csv('data_model.csv', index_col = 0)
df.sample(7)
# Out:
#               T1           F1        F2          F3         F4          F5  \
# 700.0   2.756153  2009.096474  6.655445  106.988610  24.913133  345.214591
# 341.0   1.563171  1984.395560  6.972794  132.985799  18.480269  323.263870
# 426.0   1.750613  2033.664073  5.680486   81.017478  23.693207  269.253574
# 764.0   1.722849  1984.420850  6.341668  105.275269  19.757269  292.967974
# 756.0   3.044025  1976.866009  5.856693   96.105158  22.181806  383.938404
# 686.0   3.476583  1948.515885  6.542375  116.396208  26.966870  290.173733
# 1003.0  3.006790  2056.763874  5.989947  127.151367  19.773728  270.644700
#
#               F6         T2           T3          F7   F8         F9  \
# 700.0   5.518462  78.134531  2096.056525  284.072918  1.0   8.101343
# 341.0   5.765711  72.072364  1637.085577  260.051488  0.0   5.057609
# 426.0   6.868928  65.553336  1817.644854  172.281972  0.0   6.105035
# 764.0   4.670669  75.398046  2263.701796  193.691291  1.0  10.387870
# 756.0   5.394447  78.145633  2814.382093  240.768043  1.0   7.139702
# 686.0   5.525390  72.193576  2066.567458  127.182238  1.0   8.507890
# 1003.0  6.033986  75.169986  2080.605795  187.760891  1.0   7.018037
#
#               F10
# 700.0   65.497144
# 341.0   36.077296
# 426.0   27.891888
# 764.0   68.467306
# 756.0   48.346839
# 686.0   66.487421
# 1003.0  49.876234

# %% [markdown]
# # Логистическая регрессия

# %%
X = df.drop('F8', axis=1)
y = df['F8']

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, stratify=y, shuffle=True, random_state=RAND)

print(type(X_train))
print(type(y_train))
print(X_train.shape)
print(X_test.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>
# (750, 12)
# (250, 12)

# %%
scaler = StandardScaler()
X_train_norm = scaler.fit_transform(X_train)
X_test_norm = scaler.transform(X_test)

# %%
lr = LogisticRegression(class_weight = 'balanced')
lr.fit(X_train, y_train)

y_pred = lr.predict(X_test)
y_score = lr.predict_proba(X_test)[:,1]

# %%
print('roc-auc:', roc_auc_score(y_test, y_score))
print('precision:', precision_score(y_test, y_pred))
print('recall:', recall_score(y_test, y_pred))
print('f1:', f1_score(y_test, y_pred))
print('logloss:', log_loss(y_test, y_pred))
# Out:
# roc-auc: 0.540672
# precision: 0.5179856115107914
# recall: 0.576
# f1: 0.5454545454545454
# logloss: 16.57882696166842

# %%
metrics = pd.DataFrame(
    index=['roc-auc', 'precision', 'recall', 'f1', 'logloss'])

metrics['Baseline_LR'] = [roc_auc_score(y_test, y_score),
                          precision_score(y_test, y_pred),
                          recall_score(y_test, y_pred),
                          f1_score(y_test, y_pred),
                          log_loss(y_test, y_pred)]

# %%
metrics
# Out:
#            Baseline_LR
# roc-auc       0.540672
# precision     0.517986
# recall        0.576000
# f1            0.545455
# logloss      16.578827

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_score)

roc_auc = auc(fpr, tpr)

plt.plot(fpr, tpr, color='darkorange', label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')

plt.title('Logistic Regression ROC AUC = %0.3f' % roc_auc)
plt.legend(loc="lower right")
plt.show()

# %%
parameters_grid = {
    'penalty': ['l1', 'l2', 'elasticnet'],
    'C': np.linspace(1, 1000, num=5),
    'solver': ['sag', 'saga', 'lbfgs'],
    'l1_ratio': [0.25, 0.5, 0.75],
    'max_iter': np.arange(100, 500, 100)
}

lr = LogisticRegression(class_weight='balanced')
cv = StratifiedKFold(n_splits=3, shuffle=True)
grid_cv = GridSearchCV(lr, parameters_grid,
                       scoring='roc_auc', cv=cv, verbose=2)

# %%
# %%time
# производим обучение по сетке
grid_cv.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 540 candidates, totalling 1620 fits
# [CV] END C=1.0, l1_ratio=0.25, max_iter=100, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=100, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=100, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=100, penalty=l1, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=100, penalty=l1, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=100, penalty=l1, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=100, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=100, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=100, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=100, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=100, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=100, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=100, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=100, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=100, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=100, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=100, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=100, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=100, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=100, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=100, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=100, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=100, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=100, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=100, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=100, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=100, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=200, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=200, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=200, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=200, penalty=l1, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=200, penalty=l1, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=200, penalty=l1, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=200, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=200, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=200, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=200, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=200, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=200, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=200, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=200, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=200, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=200, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=200, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=200, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=200, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=200, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=200, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=200, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=200, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=200, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=200, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=200, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=200, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=300, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=300, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=300, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=300, penalty=l1, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=300, penalty=l1, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=300, penalty=l1, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=300, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=300, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=300, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=300, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=300, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=300, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=300, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=300, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=300, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=300, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=300, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=300, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=300, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=300, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=300, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=300, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=300, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=300, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=300, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=300, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=300, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=400, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=400, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=400, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=400, penalty=l1, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=400, penalty=l1, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=400, penalty=l1, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=400, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=400, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=400, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=400, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=400, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=400, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=400, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=400, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=400, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=400, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=400, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=400, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=400, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=400, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=400, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=400, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=400, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=400, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=400, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=400, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.25, max_iter=400, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=100, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=100, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=100, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=100, penalty=l1, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=100, penalty=l1, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=100, penalty=l1, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=100, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=100, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=100, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=100, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=100, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=100, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=100, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=100, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=100, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=100, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=100, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=100, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=100, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=100, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=100, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=100, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=100, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=100, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=100, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=100, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=100, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=200, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=200, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=200, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=200, penalty=l1, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=200, penalty=l1, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=200, penalty=l1, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=200, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=200, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=200, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=200, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=200, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=200, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=200, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=200, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=200, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=200, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=200, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=200, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=200, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=200, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=200, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=200, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=200, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=200, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=200, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=200, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=200, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=300, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=300, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=300, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=300, penalty=l1, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=300, penalty=l1, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=300, penalty=l1, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=300, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=300, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=300, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=300, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=300, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=300, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=300, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=300, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=300, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=300, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=300, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=300, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=300, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=300, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=300, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=300, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=300, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=300, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=300, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=300, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=300, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=400, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=400, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=400, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=400, penalty=l1, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=400, penalty=l1, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=400, penalty=l1, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=400, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=400, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=400, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=400, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=400, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=400, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=400, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=400, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=400, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=400, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=400, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=400, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=400, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=400, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=400, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=400, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=400, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=400, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=400, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=400, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.5, max_iter=400, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=100, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=100, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=100, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=100, penalty=l1, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=100, penalty=l1, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=100, penalty=l1, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=100, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=100, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=100, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=100, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=100, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=100, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=100, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=100, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=100, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=100, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=100, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=100, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=100, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=100, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=100, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=100, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=100, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=100, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=100, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=100, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=100, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=200, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=200, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=200, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=200, penalty=l1, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=200, penalty=l1, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=200, penalty=l1, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=200, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=200, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=200, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=200, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=200, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=200, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=200, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=200, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=200, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=200, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=200, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=200, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=200, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=200, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=200, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=200, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=200, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=200, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=200, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=200, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=200, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=300, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=300, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=300, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=300, penalty=l1, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=300, penalty=l1, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=300, penalty=l1, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=300, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=300, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=300, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=300, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=300, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=300, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=300, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=300, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=300, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=300, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=300, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=300, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=300, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=300, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=300, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=300, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=300, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=300, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=300, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=300, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=300, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=400, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=400, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=400, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=400, penalty=l1, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=400, penalty=l1, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=400, penalty=l1, solver=saga; total time=   0.1s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=400, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=400, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=400, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=400, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=400, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=400, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=400, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=400, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=400, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=400, penalty=l2, solver=lbfgs; total time=   0.2s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=400, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=400, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=400, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=400, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=400, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=400, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=400, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=400, penalty=elasticnet, solver=saga; total time=   0.1s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=400, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=400, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=1.0, l1_ratio=0.75, max_iter=400, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=100, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=100, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=100, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=100, penalty=l1, solver=saga; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=100, penalty=l1, solver=saga; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=100, penalty=l1, solver=saga; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=100, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=100, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=100, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=100, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=100, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=100, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=100, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=100, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=100, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=100, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=100, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=100, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=100, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=100, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=100, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=100, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=100, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=100, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=100, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=100, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=100, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=200, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=200, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=200, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=200, penalty=l1, solver=saga; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=200, penalty=l1, solver=saga; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=200, penalty=l1, solver=saga; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=200, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=200, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=200, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=200, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=200, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=200, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=200, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=200, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=200, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=200, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=200, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=200, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=200, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=200, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=200, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=200, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=200, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=200, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=200, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=200, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=200, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=300, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=300, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=300, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=300, penalty=l1, solver=saga; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=300, penalty=l1, solver=saga; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=300, penalty=l1, solver=saga; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=300, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=300, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=300, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=300, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=300, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=300, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=300, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=300, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=300, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=300, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=300, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=300, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=300, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=300, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=300, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=300, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=300, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=300, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=300, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=300, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=300, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=400, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=400, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=400, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=400, penalty=l1, solver=saga; total time=   0.1s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=400, penalty=l1, solver=saga; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=400, penalty=l1, solver=saga; total time=   0.1s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=400, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=400, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=400, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=400, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=400, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=400, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=400, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=400, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=400, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=400, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=400, penalty=l2, solver=lbfgs; total time=   0.2s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=400, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=400, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=400, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=400, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=400, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=400, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=400, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=400, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=400, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.25, max_iter=400, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=100, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=100, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=100, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=100, penalty=l1, solver=saga; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=100, penalty=l1, solver=saga; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=100, penalty=l1, solver=saga; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=100, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=100, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=100, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=100, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=100, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=100, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=100, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=100, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=100, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=100, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=100, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=100, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=100, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=100, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=100, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=100, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=100, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=100, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=100, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=100, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=100, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=200, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=200, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=200, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=200, penalty=l1, solver=saga; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=200, penalty=l1, solver=saga; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=200, penalty=l1, solver=saga; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=200, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=200, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=200, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=200, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=200, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=200, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=200, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=200, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=200, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=200, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=200, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=200, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=200, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=200, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=200, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=200, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=200, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=200, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=200, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=200, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=200, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=300, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=300, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=300, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=300, penalty=l1, solver=saga; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=300, penalty=l1, solver=saga; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=300, penalty=l1, solver=saga; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=300, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=300, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=300, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=300, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=300, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=300, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=300, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=300, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=300, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=300, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=300, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=300, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=300, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=300, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=300, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=300, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=300, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=300, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=300, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=300, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=300, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=400, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=400, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=400, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=400, penalty=l1, solver=saga; total time=   0.0s
# [CV] END C=250.75, l1_ratio=0.5, max_iter=400, penalty=l1, solver=saga; total time=   0.0s
# ...
# [CV] END C=1000.0, l1_ratio=0.5, max_iter=200, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.5, max_iter=300, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.5, max_iter=300, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.5, max_iter=300, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.5, max_iter=300, penalty=l1, solver=saga; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.5, max_iter=300, penalty=l1, solver=saga; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.5, max_iter=300, penalty=l1, solver=saga; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.5, max_iter=300, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.5, max_iter=300, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.5, max_iter=300, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.5, max_iter=300, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.5, max_iter=300, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.5, max_iter=300, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.5, max_iter=300, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.5, max_iter=300, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.5, max_iter=300, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.5, max_iter=300, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END C=1000.0, l1_ratio=0.5, max_iter=300, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END C=1000.0, l1_ratio=0.5, max_iter=300, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.5, max_iter=300, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.5, max_iter=300, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.5, max_iter=300, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.5, max_iter=300, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.5, max_iter=300, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.5, max_iter=300, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.5, max_iter=300, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.5, max_iter=300, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.5, max_iter=300, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.5, max_iter=400, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.5, max_iter=400, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.5, max_iter=400, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.5, max_iter=400, penalty=l1, solver=saga; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.5, max_iter=400, penalty=l1, solver=saga; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.5, max_iter=400, penalty=l1, solver=saga; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.5, max_iter=400, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.5, max_iter=400, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.5, max_iter=400, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.5, max_iter=400, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.5, max_iter=400, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.5, max_iter=400, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.5, max_iter=400, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.5, max_iter=400, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.5, max_iter=400, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.5, max_iter=400, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.5, max_iter=400, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END C=1000.0, l1_ratio=0.5, max_iter=400, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.5, max_iter=400, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.5, max_iter=400, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.5, max_iter=400, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.5, max_iter=400, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.5, max_iter=400, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.5, max_iter=400, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.5, max_iter=400, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.5, max_iter=400, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.5, max_iter=400, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=100, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=100, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=100, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=100, penalty=l1, solver=saga; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=100, penalty=l1, solver=saga; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=100, penalty=l1, solver=saga; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=100, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=100, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=100, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=100, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=100, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=100, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=100, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=100, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=100, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=100, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=100, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=100, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=100, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=100, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=100, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=100, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=100, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=100, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=100, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=100, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=100, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=200, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=200, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=200, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=200, penalty=l1, solver=saga; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=200, penalty=l1, solver=saga; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=200, penalty=l1, solver=saga; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=200, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=200, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=200, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=200, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=200, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=200, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=200, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=200, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=200, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=200, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=200, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=200, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=200, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=200, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=200, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=200, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=200, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=200, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=200, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=200, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=200, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=300, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=300, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=300, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=300, penalty=l1, solver=saga; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=300, penalty=l1, solver=saga; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=300, penalty=l1, solver=saga; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=300, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=300, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=300, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=300, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=300, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=300, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=300, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=300, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=300, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=300, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=300, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=300, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=300, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=300, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=300, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=300, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=300, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=300, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=300, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=300, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=300, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=400, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=400, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=400, penalty=l1, solver=sag; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=400, penalty=l1, solver=saga; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=400, penalty=l1, solver=saga; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=400, penalty=l1, solver=saga; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=400, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=400, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=400, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=400, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=400, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=400, penalty=l2, solver=sag; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=400, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=400, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=400, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=400, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=400, penalty=l2, solver=lbfgs; total time=   0.1s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=400, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=400, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=400, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=400, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=400, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=400, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=400, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=400, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=400, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=1000.0, l1_ratio=0.75, max_iter=400, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# Wall time: 1min 13s
# GridSearchCV(cv=StratifiedKFold(n_splits=3, random_state=None, shuffle=True),
#              estimator=LogisticRegression(class_weight='balanced'),
#              param_grid={'C': array([   1.  ,  250.75,  500.5 ,  750.25, 1000.  ]),
#                          'l1_ratio': [0.25, 0.5, 0.75],
#                          'max_iter': array([100, 200, 300, 400]),
#                          'penalty': ['l1', 'l2', 'elasticnet'],
#                          'solver': ['sag', 'saga', 'lbfgs']},
#              scoring='roc_auc', verbose=2)

# %%
print(grid_cv.best_score_)
print(grid_cv.best_params_)
# Out:
# 0.5625846144393242
# {'C': 750.25, 'l1_ratio': 0.25, 'max_iter': 100, 'penalty': 'l2', 'solver': 'lbfgs'}

# %%
best_params = {'C': 750.25, 
               'l1_ratio': 0.25,
               'max_iter': 100, 
               'penalty': 'l2', 
               'solver': 'lbfgs'}

# %%
lr_gr = LogisticRegression(**best_params, class_weight='balanced')
lr_gr.fit(X_train, y_train)

y_pred_gr = lr_gr.predict(X_test)
y_score_gr = lr_gr.predict_proba(X_test)[:,1]

# %%
print('roc-auc:', roc_auc_score(y_test, y_score_gr))
print('precision:', precision_score(y_test, y_pred_gr))
print('recall:', recall_score(y_test, y_pred_gr))
print('f1:', f1_score(y_test, y_pred_gr))
print('logloss:', log_loss(y_test, y_pred_gr))
# Out:
# roc-auc: 0.537728
# precision: 0.5352112676056338
# recall: 0.608
# f1: 0.5692883895131087
# logloss: 15.888048235380488

# %%
fpr_2, tpr_2, thresholds_2 = roc_curve(y_test, y_score_gr)

roc_auc_2 = auc(fpr_2, tpr_2)

plt.plot(fpr, tpr, color='darkorange', label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot(fpr_2, tpr_2, color='green', label='ROC curve (area = %0.2f)' % roc_auc_2)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')

plt.title('Logistic Regression ROC AUC = %0.3f' % roc_auc)
plt.legend(loc="lower right")
plt.show()

# %%
metrics['Grid_LR'] = [roc_auc_score(y_test, y_score_gr),
                      precision_score(y_test, y_pred_gr),
                      recall_score(y_test, y_pred_gr),
                      f1_score(y_test, y_pred_gr),
                      log_loss(y_test, y_pred_gr)]

# %%
metrics[:-1].style.highlight_max(axis=1, color='lightblue')
# Out:
# <style type="text/css">
# #T_4350f_row0_col0, #T_4350f_row1_col1, #T_4350f_row2_col1, #T_4350f_row3_col1 {
#   background-color: lightblue;
# }
# </style>
# <table id="T_4350f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Baseline_LR</th>
#       <th class="col_heading level0 col1" >Grid_LR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4350f_level0_row0" class="row_heading level0 row0" >roc-auc</th>
#       <td id="T_4350f_row0_col0" class="data row0 col0" >0.540672</td>
#       <td id="T_4350f_row0_col1" class="data row0 col1" >0.537728</td>
#     </tr>
#     <tr>
#       <th id="T_4350f_level0_row1" class="row_heading level0 row1" >precision</th>
#       <td id="T_4350f_row1_col0" class="data row1 col0" >0.517986</td>
#       <td id="T_4350f_row1_col1" class="data row1 col1" >0.535211</td>
#     </tr>
#     <tr>
#       <th id="T_4350f_level0_row2" class="row_heading level0 row2" >recall</th>
#       <td id="T_4350f_row2_col0" class="data row2 col0" >0.576000</td>
#       <td id="T_4350f_row2_col1" class="data row2 col1" >0.608000</td>
#     </tr>
#     <tr>
#       <th id="T_4350f_level0_row3" class="row_heading level0 row3" >f1</th>
#       <td id="T_4350f_row3_col0" class="data row3 col0" >0.545455</td>
#       <td id="T_4350f_row3_col1" class="data row3 col1" >0.569288</td>
#     </tr>
#   </tbody>
# </table>

# %%
import shap
explainer = shap.LinearExplainer(lr_gr, X_train, feature_dependence="independent")
shap_values = explainer(X_test)

# %%
# summary plot
shap.summary_plot(shap_values, X_test)

# %%
lr_gr.coef_
# Out:
# array([[-0.01295598, -0.00200438, -0.01027628,  0.0022965 , -0.02245212,
#          0.00186585,  0.04990313,  0.02585235,  0.00014778,  0.00039639,
#          0.03806755,  0.01539032]])

# %%
feature_imp = pd.DataFrame()
feature_imp['feature'] = X.columns
feature_imp['imp'] = lr_gr.coef_[0]
feature_imp = feature_imp.sort_values(by='imp', ascending=False)

# %%
feature_imp
# Out:
#    feature       imp
# 6       F6  0.049903
# 10      F9  0.038068
# 7       T2  0.025852
# 11     F10  0.015390
# 3       F3  0.002297
# 5       F5  0.001866
# 9       F7  0.000396
# 8       T3  0.000148
# 1       F1 -0.002004
# 2       F2 -0.010276
# 0       T1 -0.012956
# 4       F4 -0.022452

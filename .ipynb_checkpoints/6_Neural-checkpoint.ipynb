# %%
import numpy as np
import pandas as pd

from keras.models import Sequential
from keras.layers import Dense

from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('data_model.csv', index_col = 0)
df.sample(5)
# Out:
#              T1           F1           F2          F3         F4          F5  \
# 625.0  3.709140  2072.959799   563.965041   86.803447  25.262955  285.407901
# 811.0  2.869846  1964.749492   376.553340  146.098051  20.646568  277.938770
# 635.0  2.993124  1873.098881  1315.304892  114.275490  23.712518  246.822019
# 79.0   2.896836  1929.520185   386.793182  147.304327  22.529384  306.854197
# 68.0   2.681941  1843.182562  1185.993150  106.823808  19.332700  320.363019
#
#                 F6         T2           T3          F7   F8         F9  \
# 625.0    26.544979  71.337023  3041.020112  133.021557  1.0   7.318079
# 811.0   735.086541  79.450448  2805.158519  309.786667  1.0   6.431891
# 635.0  1177.612670  71.175111  1782.924684  160.294496  1.0   8.230811
# 79.0    207.521157  69.094186  1869.980089  138.967712  0.0   7.984146
# 68.0     75.240020  71.215032  3377.328044   92.447865  0.0  10.622886
#
#              F10
# 625.0  48.090478
# 811.0  53.806119
# 635.0  46.367372
# 79.0   51.058868
# 68.0   47.549771

# %%
df_1 = df.drop(['F1', 'F4', 'F5', 'F6', 'T2', 'F7', 'F8', 'F10'], axis = 1)

# %%
ds = df.values
X = ds[:,0:4]
y = ds[:,0]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3,random_state = 42)

#res= clf._predict_proba_lr(X_test,Y_test)

X_train.shape
# Out:
# (700, 4)

# %%
# Среднее значение
mean = X_train.mean(axis=0)
# Стандартное отклонение
std = X_train.std(axis=0)
X_train -= mean
X_train /= std
X_test -= mean
X_test /= std

# %% [markdown]
# Создали сеть

# %%
model = Sequential()
model.add(Dense(128, activation='relu', input_shape=(X_train.shape[1],)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse', metrics=['mae'])

# %% [markdown]
# Обучаем

# %%
model.fit(X_train, y_train, epochs=10, batch_size=1, verbose=2)
# Out:
# Epoch 1/10
# 700/700 - 1s - loss: 1.2204 - mae: 0.7329 - 843ms/epoch - 1ms/step
# Epoch 2/10
# 700/700 - 0s - loss: 0.0431 - mae: 0.1582 - 489ms/epoch - 699us/step
# Epoch 3/10
# 700/700 - 0s - loss: 0.0079 - mae: 0.0653 - 490ms/epoch - 699us/step
# Epoch 4/10
# 700/700 - 1s - loss: 0.0043 - mae: 0.0498 - 514ms/epoch - 734us/step
# Epoch 5/10
# 700/700 - 1s - loss: 0.0034 - mae: 0.0446 - 534ms/epoch - 763us/step
# Epoch 6/10
# 700/700 - 1s - loss: 0.0031 - mae: 0.0434 - 508ms/epoch - 725us/step
# Epoch 7/10
# 700/700 - 1s - loss: 0.0024 - mae: 0.0382 - 549ms/epoch - 785us/step
# Epoch 8/10
# 700/700 - 0s - loss: 0.0021 - mae: 0.0366 - 487ms/epoch - 696us/step
# Epoch 9/10
# 700/700 - 0s - loss: 0.0027 - mae: 0.0394 - 493ms/epoch - 704us/step
# Epoch 10/10
# 700/700 - 1s - loss: 0.0021 - mae: 0.0355 - 505ms/epoch - 721us/step

# %% [markdown]
# Оценка точности работы сети

# %%
mse, mae = model.evaluate(X_test, y_test, verbose=0)

# %%
print("Средняя абсолютная ошибка (ед.):", mae)
# Out:
# Средняя абсолютная ошибка (ед.): 0.04601433128118515

# %% [markdown]
# Использование сети для предсказания соотношения

# %%
pred = model.predict(X_test)

# %%
print("Предсказанное соотношение:", pred[1][0], ", правильное соотношение:", y_test[1])
# Out:
# Предсказанное соотношение: 1.9883167 , правильное соотношение: 1.85729150266508

# %%
# Предсказание vs правильный ответ
for i in range(len(pred)):
  print("Сеть сказала: ", np.round(pred[i],2), ", а верный ответ: ", np.round(y_test[i],2), ", разница: ", np.round(pred[i] - y_test[i],2))
# Out:
# Сеть сказала:  [2.42] , а верный ответ:  2.46 , разница:  [-0.03]
# Сеть сказала:  [1.99] , а верный ответ:  1.86 , разница:  [0.13]
# Сеть сказала:  [3.63] , а верный ответ:  3.63 , разница:  [0.]
# Сеть сказала:  [4.68] , а верный ответ:  4.71 , разница:  [-0.03]
# Сеть сказала:  [2.89] , а верный ответ:  2.93 , разница:  [-0.04]
# Сеть сказала:  [2.47] , а верный ответ:  2.52 , разница:  [-0.05]
# Сеть сказала:  [4.39] , а верный ответ:  4.46 , разница:  [-0.07]
# Сеть сказала:  [1.54] , а верный ответ:  1.52 , разница:  [0.02]
# Сеть сказала:  [4.82] , а верный ответ:  4.86 , разница:  [-0.05]
# Сеть сказала:  [3.59] , а верный ответ:  3.54 , разница:  [0.05]
# Сеть сказала:  [2.3] , а верный ответ:  2.32 , разница:  [-0.02]
# Сеть сказала:  [4.35] , а верный ответ:  4.43 , разница:  [-0.08]
# Сеть сказала:  [4.09] , а верный ответ:  4.09 , разница:  [0.]
# Сеть сказала:  [3.] , а верный ответ:  3.0 , разница:  [0.]
# Сеть сказала:  [1.97] , а верный ответ:  2.02 , разница:  [-0.04]
# Сеть сказала:  [2.43] , а верный ответ:  2.42 , разница:  [0.01]
# Сеть сказала:  [2.01] , а верный ответ:  2.02 , разница:  [-0.01]
# Сеть сказала:  [4.06] , а верный ответ:  4.08 , разница:  [-0.02]
# Сеть сказала:  [2.39] , а верный ответ:  2.45 , разница:  [-0.06]
# Сеть сказала:  [4.48] , а верный ответ:  4.53 , разница:  [-0.04]
# Сеть сказала:  [3.92] , а верный ответ:  3.93 , разница:  [-0.01]
# Сеть сказала:  [4.35] , а верный ответ:  4.42 , разница:  [-0.07]
# Сеть сказала:  [2.78] , а верный ответ:  2.74 , разница:  [0.04]
# Сеть сказала:  [2.56] , а верный ответ:  2.61 , разница:  [-0.05]
# Сеть сказала:  [2.45] , а верный ответ:  2.51 , разница:  [-0.06]
# Сеть сказала:  [3.66] , а верный ответ:  3.71 , разница:  [-0.05]
# Сеть сказала:  [2.25] , а верный ответ:  2.32 , разница:  [-0.07]
# Сеть сказала:  [3.67] , а верный ответ:  3.68 , разница:  [-0.01]
# Сеть сказала:  [1.92] , а верный ответ:  1.86 , разница:  [0.05]
# Сеть сказала:  [2.27] , а верный ответ:  2.28 , разница:  [-0.01]
# Сеть сказала:  [2.97] , а верный ответ:  2.91 , разница:  [0.07]
# Сеть сказала:  [2.73] , а верный ответ:  2.76 , разница:  [-0.03]
# Сеть сказала:  [2.71] , а верный ответ:  2.77 , разница:  [-0.06]
# Сеть сказала:  [4.4] , а верный ответ:  4.42 , разница:  [-0.02]
# Сеть сказала:  [1.98] , а верный ответ:  1.99 , разница:  [-0.01]
# Сеть сказала:  [2.89] , а верный ответ:  2.93 , разница:  [-0.04]
# Сеть сказала:  [3.42] , а верный ответ:  3.42 , разница:  [-0.]
# Сеть сказала:  [3.6] , а верный ответ:  3.65 , разница:  [-0.05]
# Сеть сказала:  [2.87] , а верный ответ:  2.92 , разница:  [-0.05]
# Сеть сказала:  [3.12] , а верный ответ:  3.18 , разница:  [-0.05]
# Сеть сказала:  [4.5] , а верный ответ:  4.53 , разница:  [-0.02]
# Сеть сказала:  [2.14] , а верный ответ:  2.15 , разница:  [-0.01]
# Сеть сказала:  [2.13] , а верный ответ:  2.2 , разница:  [-0.07]
# Сеть сказала:  [2.66] , а верный ответ:  2.68 , разница:  [-0.03]
# Сеть сказала:  [4.53] , а верный ответ:  4.64 , разница:  [-0.12]
# Сеть сказала:  [3.22] , а верный ответ:  3.18 , разница:  [0.04]
# Сеть сказала:  [3.33] , а верный ответ:  3.39 , разница:  [-0.06]
# Сеть сказала:  [4.68] , а верный ответ:  4.65 , разница:  [0.03]
# Сеть сказала:  [4.03] , а верный ответ:  4.0 , разница:  [0.03]
# Сеть сказала:  [1.65] , а верный ответ:  1.64 , разница:  [0.01]
# Сеть сказала:  [2.59] , а верный ответ:  2.59 , разница:  [0.]
# Сеть сказала:  [3.31] , а верный ответ:  3.4 , разница:  [-0.08]
# Сеть сказала:  [2.44] , а верный ответ:  2.45 , разница:  [-0.01]
# Сеть сказала:  [2.66] , а верный ответ:  2.57 , разница:  [0.09]
# Сеть сказала:  [2.45] , а верный ответ:  2.5 , разница:  [-0.05]
# Сеть сказала:  [1.69] , а верный ответ:  1.77 , разница:  [-0.08]
# Сеть сказала:  [3.18] , а верный ответ:  3.28 , разница:  [-0.1]
# Сеть сказала:  [3.03] , а верный ответ:  2.92 , разница:  [0.11]
# Сеть сказала:  [2.93] , а верный ответ:  2.93 , разница:  [0.01]
# Сеть сказала:  [2.32] , а верный ответ:  2.32 , разница:  [-0.]
# Сеть сказала:  [3.3] , а верный ответ:  3.3 , разница:  [0.]
# Сеть сказала:  [4.55] , а верный ответ:  4.62 , разница:  [-0.06]
# Сеть сказала:  [2.33] , а верный ответ:  2.38 , разница:  [-0.05]
# Сеть сказала:  [3.16] , а верный ответ:  3.13 , разница:  [0.04]
# Сеть сказала:  [3.66] , а верный ответ:  3.71 , разница:  [-0.05]
# Сеть сказала:  [2.15] , а верный ответ:  2.15 , разница:  [-0.01]
# Сеть сказала:  [2.4] , а верный ответ:  2.42 , разница:  [-0.01]
# Сеть сказала:  [3.47] , а верный ответ:  3.5 , разница:  [-0.03]
# Сеть сказала:  [2.56] , а верный ответ:  2.54 , разница:  [0.03]
# Сеть сказала:  [3.02] , а верный ответ:  3.01 , разница:  [0.01]
# Сеть сказала:  [3.51] , а верный ответ:  3.49 , разница:  [0.02]
# Сеть сказала:  [2.67] , а верный ответ:  2.67 , разница:  [-0.]
# Сеть сказала:  [1.51] , а верный ответ:  1.54 , разница:  [-0.03]
# Сеть сказала:  [3.48] , а верный ответ:  3.5 , разница:  [-0.02]
# Сеть сказала:  [3.59] , а верный ответ:  3.63 , разница:  [-0.04]
# Сеть сказала:  [3.09] , а верный ответ:  3.08 , разница:  [0.]
# Сеть сказала:  [1.87] , а верный ответ:  1.79 , разница:  [0.08]
# Сеть сказала:  [2.92] , а верный ответ:  3.03 , разница:  [-0.12]
# Сеть сказала:  [4.37] , а верный ответ:  4.3 , разница:  [0.07]
# Сеть сказала:  [3.09] , а верный ответ:  2.93 , разница:  [0.16]
# Сеть сказала:  [2.77] , а верный ответ:  2.76 , разница:  [0.02]
# Сеть сказала:  [2.61] , а верный ответ:  2.68 , разница:  [-0.07]
# Сеть сказала:  [3.76] , а верный ответ:  3.86 , разница:  [-0.1]
# Сеть сказала:  [3.11] , а верный ответ:  3.12 , разница:  [-0.01]
# Сеть сказала:  [3.35] , а верный ответ:  3.36 , разница:  [-0.01]
# Сеть сказала:  [1.61] , а верный ответ:  1.62 , разница:  [-0.01]
# Сеть сказала:  [3.73] , а верный ответ:  3.71 , разница:  [0.02]
# Сеть сказала:  [1.35] , а верный ответ:  1.4 , разница:  [-0.05]
# Сеть сказала:  [4.12] , а верный ответ:  4.23 , разница:  [-0.11]
# Сеть сказала:  [2.24] , а верный ответ:  2.22 , разница:  [0.02]
# Сеть сказала:  [4.01] , а верный ответ:  4.03 , разница:  [-0.02]
# Сеть сказала:  [2.34] , а верный ответ:  2.41 , разница:  [-0.07]
# Сеть сказала:  [2.8] , а верный ответ:  2.87 , разница:  [-0.07]
# Сеть сказала:  [1.7] , а верный ответ:  1.53 , разница:  [0.17]
# Сеть сказала:  [2.72] , а верный ответ:  2.74 , разница:  [-0.03]
# Сеть сказала:  [2.52] , а верный ответ:  2.59 , разница:  [-0.07]
# Сеть сказала:  [1.72] , а верный ответ:  1.8 , разница:  [-0.07]
# Сеть сказала:  [2.09] , а верный ответ:  2.14 , разница:  [-0.05]
# Сеть сказала:  [1.69] , а верный ответ:  1.71 , разница:  [-0.01]
# Сеть сказала:  [3.55] , а верный ответ:  3.66 , разница:  [-0.1]
# Сеть сказала:  [2.43] , а верный ответ:  2.5 , разница:  [-0.07]
# Сеть сказала:  [2.55] , а верный ответ:  2.54 , разница:  [0.]
# Сеть сказала:  [2.2] , а верный ответ:  2.26 , разница:  [-0.06]
# Сеть сказала:  [3.06] , а верный ответ:  2.89 , разница:  [0.16]
# Сеть сказала:  [2.12] , а верный ответ:  2.15 , разница:  [-0.03]
# Сеть сказала:  [3.63] , а верный ответ:  3.71 , разница:  [-0.08]
# Сеть сказала:  [2.56] , а верный ответ:  2.58 , разница:  [-0.03]
# Сеть сказала:  [3.52] , а верный ответ:  3.62 , разница:  [-0.1]
# Сеть сказала:  [3.49] , а верный ответ:  3.58 , разница:  [-0.09]
# Сеть сказала:  [2.68] , а верный ответ:  2.72 , разница:  [-0.04]
# Сеть сказала:  [2.4] , а верный ответ:  2.41 , разница:  [-0.01]
# Сеть сказала:  [3.14] , а верный ответ:  2.98 , разница:  [0.17]
# Сеть сказала:  [2.24] , а верный ответ:  2.2 , разница:  [0.04]
# Сеть сказала:  [3.97] , а верный ответ:  3.99 , разница:  [-0.02]
# Сеть сказала:  [3.35] , а верный ответ:  3.32 , разница:  [0.03]
# Сеть сказала:  [2.31] , а верный ответ:  2.28 , разница:  [0.03]
# Сеть сказала:  [3.58] , а верный ответ:  3.61 , разница:  [-0.03]
# Сеть сказала:  [3.93] , а верный ответ:  3.96 , разница:  [-0.03]
# Сеть сказала:  [1.75] , а верный ответ:  1.82 , разница:  [-0.07]
# Сеть сказала:  [3.23] , а верный ответ:  3.22 , разница:  [0.]
# Сеть сказала:  [1.2] , а верный ответ:  1.09 , разница:  [0.11]
# Сеть сказала:  [3.49] , а верный ответ:  3.49 , разница:  [0.]
# Сеть сказала:  [2.5] , а верный ответ:  2.55 , разница:  [-0.05]
# Сеть сказала:  [2.38] , а верный ответ:  2.42 , разница:  [-0.04]
# Сеть сказала:  [2.84] , а верный ответ:  2.82 , разница:  [0.02]
# Сеть сказала:  [3.74] , а верный ответ:  3.86 , разница:  [-0.12]
# Сеть сказала:  [4.11] , а верный ответ:  4.2 , разница:  [-0.09]
# Сеть сказала:  [2.09] , а верный ответ:  2.13 , разница:  [-0.04]
# Сеть сказала:  [4.33] , а верный ответ:  4.41 , разница:  [-0.09]
# Сеть сказала:  [3.38] , а верный ответ:  3.37 , разница:  [0.01]
# Сеть сказала:  [3.2] , а верный ответ:  3.28 , разница:  [-0.08]
# Сеть сказала:  [1.65] , а верный ответ:  1.71 , разница:  [-0.06]
# Сеть сказала:  [2.79] , а верный ответ:  2.79 , разница:  [-0.]
# Сеть сказала:  [2.23] , а верный ответ:  2.27 , разница:  [-0.04]
# Сеть сказала:  [2.31] , а верный ответ:  2.36 , разница:  [-0.06]
# Сеть сказала:  [4.15] , а верный ответ:  4.26 , разница:  [-0.1]
# Сеть сказала:  [2.13] , а верный ответ:  2.17 , разница:  [-0.04]
# Сеть сказала:  [2.25] , а верный ответ:  2.05 , разница:  [0.2]
# Сеть сказала:  [1.87] , а верный ответ:  1.86 , разница:  [0.01]
# Сеть сказала:  [3.15] , а верный ответ:  3.13 , разница:  [0.03]
# Сеть сказала:  [2.36] , а верный ответ:  2.34 , разница:  [0.02]
# Сеть сказала:  [2.49] , а верный ответ:  2.47 , разница:  [0.01]
# Сеть сказала:  [2.73] , а верный ответ:  2.78 , разница:  [-0.05]
# Сеть сказала:  [1.8] , а верный ответ:  1.82 , разница:  [-0.02]
# Сеть сказала:  [4.45] , а верный ответ:  4.53 , разница:  [-0.08]
# Сеть сказала:  [2.8] , а верный ответ:  2.81 , разница:  [-0.01]
# Сеть сказала:  [2.96] , а верный ответ:  2.99 , разница:  [-0.03]
# Сеть сказала:  [2.51] , а верный ответ:  2.58 , разница:  [-0.07]
# Сеть сказала:  [5.02] , а верный ответ:  5.12 , разница:  [-0.1]
# Сеть сказала:  [1.27] , а верный ответ:  1.2 , разница:  [0.07]
# Сеть сказала:  [1.85] , а верный ответ:  1.88 , разница:  [-0.03]
# Сеть сказала:  [3.71] , а верный ответ:  3.78 , разница:  [-0.07]
# Сеть сказала:  [3.14] , а верный ответ:  3.11 , разница:  [0.03]
# Сеть сказала:  [3.49] , а верный ответ:  3.54 , разница:  [-0.05]
# Сеть сказала:  [2.67] , а верный ответ:  2.7 , разница:  [-0.02]
# Сеть сказала:  [1.75] , а верный ответ:  1.75 , разница:  [0.01]
# Сеть сказала:  [3.09] , а верный ответ:  3.11 , разница:  [-0.02]
# Сеть сказала:  [3.79] , а верный ответ:  3.88 , разница:  [-0.1]
# Сеть сказала:  [2.11] , а верный ответ:  2.1 , разница:  [0.01]
# Сеть сказала:  [4.6] , а верный ответ:  4.7 , разница:  [-0.1]
# Сеть сказала:  [2.82] , а верный ответ:  2.83 , разница:  [-0.01]
# Сеть сказала:  [3.23] , а верный ответ:  3.3 , разница:  [-0.08]
# Сеть сказала:  [3.17] , а верный ответ:  3.24 , разница:  [-0.08]
# Сеть сказала:  [1.28] , а верный ответ:  1.26 , разница:  [0.01]
# Сеть сказала:  [2.64] , а верный ответ:  2.66 , разница:  [-0.02]
# Сеть сказала:  [3.08] , а верный ответ:  3.09 , разница:  [-0.]
# Сеть сказала:  [2.18] , а верный ответ:  2.19 , разница:  [-0.01]
# Сеть сказала:  [1.56] , а верный ответ:  1.57 , разница:  [-0.01]
# Сеть сказала:  [2.2] , а верный ответ:  2.22 , разница:  [-0.03]
# Сеть сказала:  [3.3] , а верный ответ:  3.31 , разница:  [-0.]
# Сеть сказала:  [2.51] , а верный ответ:  2.49 , разница:  [0.02]
# Сеть сказала:  [1.46] , а верный ответ:  1.51 , разница:  [-0.06]
# Сеть сказала:  [3.07] , а верный ответ:  3.11 , разница:  [-0.04]
# Сеть сказала:  [3.96] , а верный ответ:  3.99 , разница:  [-0.03]
# Сеть сказала:  [2.25] , а верный ответ:  2.19 , разница:  [0.06]
# Сеть сказала:  [3.24] , а верный ответ:  3.27 , разница:  [-0.03]
# Сеть сказала:  [3.84] , а верный ответ:  3.9 , разница:  [-0.06]
# Сеть сказала:  [1.75] , а верный ответ:  1.8 , разница:  [-0.05]
# Сеть сказала:  [2.9] , а верный ответ:  2.89 , разница:  [0.01]
# Сеть сказала:  [2.67] , а верный ответ:  2.64 , разница:  [0.03]
# Сеть сказала:  [4.19] , а верный ответ:  4.22 , разница:  [-0.03]
# Сеть сказала:  [2.99] , а верный ответ:  2.99 , разница:  [0.]
# Сеть сказала:  [3.63] , а верный ответ:  3.67 , разница:  [-0.04]
# Сеть сказала:  [1.97] , а верный ответ:  1.98 , разница:  [-0.01]
# Сеть сказала:  [4.88] , а верный ответ:  4.75 , разница:  [0.14]
# Сеть сказала:  [3.68] , а верный ответ:  3.65 , разница:  [0.02]
# Сеть сказала:  [2.34] , а верный ответ:  2.38 , разница:  [-0.04]
# Сеть сказала:  [2.04] , а верный ответ:  2.11 , разница:  [-0.07]
# Сеть сказала:  [2.89] , а верный ответ:  2.86 , разница:  [0.02]
# Сеть сказала:  [3.28] , а верный ответ:  3.26 , разница:  [0.02]
# Сеть сказала:  [2.14] , а верный ответ:  2.17 , разница:  [-0.03]
# Сеть сказала:  [2.57] , а верный ответ:  2.58 , разница:  [-0.01]
# Сеть сказала:  [3.58] , а верный ответ:  3.67 , разница:  [-0.09]
# Сеть сказала:  [3.75] , а верный ответ:  3.8 , разница:  [-0.05]
# Сеть сказала:  [2.3] , а верный ответ:  2.37 , разница:  [-0.06]
# Сеть сказала:  [3.6] , а верный ответ:  3.64 , разница:  [-0.03]
# Сеть сказала:  [2.96] , а верный ответ:  2.99 , разница:  [-0.04]
# Сеть сказала:  [1.47] , а верный ответ:  1.54 , разница:  [-0.07]
# Сеть сказала:  [2.67] , а верный ответ:  2.62 , разница:  [0.04]
# Сеть сказала:  [2.5] , а верный ответ:  2.53 , разница:  [-0.03]
# Сеть сказала:  [1.98] , а верный ответ:  1.98 , разница:  [-0.]
# Сеть сказала:  [2.55] , а верный ответ:  2.58 , разница:  [-0.03]
# Сеть сказала:  [3.32] , а верный ответ:  3.36 , разница:  [-0.04]
# Сеть сказала:  [3.06] , а верный ответ:  3.05 , разница:  [0.01]
# Сеть сказала:  [3.08] , а верный ответ:  3.13 , разница:  [-0.05]
# Сеть сказала:  [1.48] , а верный ответ:  1.48 , разница:  [-0.]
# Сеть сказала:  [4.09] , а верный ответ:  4.11 , разница:  [-0.02]
# Сеть сказала:  [2.29] , а верный ответ:  2.29 , разница:  [-0.]
# Сеть сказала:  [2.76] , а верный ответ:  2.8 , разница:  [-0.04]
# Сеть сказала:  [2.9] , а верный ответ:  2.89 , разница:  [0.01]
# Сеть сказала:  [3.38] , а верный ответ:  3.45 , разница:  [-0.07]
# Сеть сказала:  [2.7] , а верный ответ:  2.7 , разница:  [-0.]
# Сеть сказала:  [2.96] , а верный ответ:  2.98 , разница:  [-0.02]
# Сеть сказала:  [2.93] , а верный ответ:  2.98 , разница:  [-0.05]
# Сеть сказала:  [2.49] , а верный ответ:  2.56 , разница:  [-0.07]
# Сеть сказала:  [1.55] , а верный ответ:  1.56 , разница:  [-0.01]
# Сеть сказала:  [4.51] , а верный ответ:  4.59 , разница:  [-0.08]
# Сеть сказала:  [2.59] , а верный ответ:  2.63 , разница:  [-0.04]
# Сеть сказала:  [2.4] , а верный ответ:  2.44 , разница:  [-0.04]
# Сеть сказала:  [2.88] , а верный ответ:  2.95 , разница:  [-0.07]
# Сеть сказала:  [3.26] , а верный ответ:  3.27 , разница:  [-0.01]
# Сеть сказала:  [3.03] , а верный ответ:  3.1 , разница:  [-0.08]
# Сеть сказала:  [4.27] , а верный ответ:  4.34 , разница:  [-0.06]
# Сеть сказала:  [4.07] , а верный ответ:  4.18 , разница:  [-0.11]
# Сеть сказала:  [1.69] , а верный ответ:  1.65 , разница:  [0.04]
# Сеть сказала:  [1.83] , а верный ответ:  1.86 , разница:  [-0.03]
# Сеть сказала:  [3.33] , а верный ответ:  3.4 , разница:  [-0.07]
# Сеть сказала:  [2.01] , а верный ответ:  2.1 , разница:  [-0.09]
# Сеть сказала:  [2.47] , а верный ответ:  2.52 , разница:  [-0.05]
# Сеть сказала:  [1.98] , а верный ответ:  1.97 , разница:  [0.01]
# Сеть сказала:  [2.66] , а верный ответ:  2.75 , разница:  [-0.09]
# Сеть сказала:  [2.76] , а верный ответ:  2.76 , разница:  [-0.]
# Сеть сказала:  [3.07] , а верный ответ:  3.02 , разница:  [0.05]
# Сеть сказала:  [2.83] , а верный ответ:  2.93 , разница:  [-0.09]
# Сеть сказала:  [2.84] , а верный ответ:  2.92 , разница:  [-0.08]
# Сеть сказала:  [3.18] , а верный ответ:  3.28 , разница:  [-0.1]
# Сеть сказала:  [5.66] , а верный ответ:  5.59 , разница:  [0.07]
# Сеть сказала:  [4.25] , а верный ответ:  4.27 , разница:  [-0.02]
# Сеть сказала:  [4.32] , а верный ответ:  4.38 , разница:  [-0.06]
# Сеть сказала:  [2.21] , а верный ответ:  2.33 , разница:  [-0.13]
# Сеть сказала:  [1.88] , а верный ответ:  1.86 , разница:  [0.02]
# Сеть сказала:  [3.] , а верный ответ:  3.01 , разница:  [-0.01]
# Сеть сказала:  [2.69] , а верный ответ:  2.75 , разница:  [-0.06]
# Сеть сказала:  [4.6] , а верный ответ:  4.66 , разница:  [-0.06]
# Сеть сказала:  [3.55] , а верный ответ:  3.57 , разница:  [-0.02]
# Сеть сказала:  [2.84] , а верный ответ:  2.92 , разница:  [-0.08]
# Сеть сказала:  [3.05] , а верный ответ:  3.1 , разница:  [-0.06]
# Сеть сказала:  [2.83] , а верный ответ:  2.9 , разница:  [-0.06]
# Сеть сказала:  [1.04] , а верный ответ:  1.04 , разница:  [-0.01]
# Сеть сказала:  [3.15] , а верный ответ:  3.2 , разница:  [-0.05]
# Сеть сказала:  [2.85] , а верный ответ:  2.9 , разница:  [-0.06]
# Сеть сказала:  [1.68] , а верный ответ:  1.65 , разница:  [0.03]
# Сеть сказала:  [2.82] , а верный ответ:  2.87 , разница:  [-0.05]
# Сеть сказала:  [2.15] , а верный ответ:  2.15 , разница:  [-0.]
# Сеть сказала:  [3.66] , а верный ответ:  3.72 , разница:  [-0.06]
# Сеть сказала:  [2.81] , а верный ответ:  2.83 , разница:  [-0.02]
# Сеть сказала:  [4.23] , а верный ответ:  4.27 , разница:  [-0.04]
# Сеть сказала:  [1.07] , а верный ответ:  0.96 , разница:  [0.11]
# Сеть сказала:  [2.32] , а верный ответ:  2.4 , разница:  [-0.08]
# Сеть сказала:  [2.78] , а верный ответ:  2.77 , разница:  [0.01]
# Сеть сказала:  [5.03] , а верный ответ:  5.05 , разница:  [-0.02]
# Сеть сказала:  [1.96] , а верный ответ:  1.93 , разница:  [0.03]
# Сеть сказала:  [3.84] , а верный ответ:  3.95 , разница:  [-0.11]
# Сеть сказала:  [4.08] , а верный ответ:  4.11 , разница:  [-0.03]
# Сеть сказала:  [2.71] , а верный ответ:  2.72 , разница:  [-0.01]
# Сеть сказала:  [0.95] , а верный ответ:  0.93 , разница:  [0.02]
# Сеть сказала:  [0.49] , а верный ответ:  0.6 , разница:  [-0.11]
# Сеть сказала:  [1.08] , а верный ответ:  1.07 , разница:  [0.01]
# Сеть сказала:  [2.71] , а верный ответ:  2.7 , разница:  [0.01]
# Сеть сказала:  [2.49] , а верный ответ:  2.5 , разница:  [-0.]
# Сеть сказала:  [3.71] , а верный ответ:  3.8 , разница:  [-0.09]
# Сеть сказала:  [1.65] , а верный ответ:  1.66 , разница:  [-0.01]
# Сеть сказала:  [3.3] , а верный ответ:  3.28 , разница:  [0.02]
# Сеть сказала:  [4.02] , а верный ответ:  4.11 , разница:  [-0.09]
# Сеть сказала:  [2.64] , а верный ответ:  2.69 , разница:  [-0.06]
# Сеть сказала:  [3.7] , а верный ответ:  3.53 , разница:  [0.17]
# Сеть сказала:  [2.96] , а верный ответ:  3.01 , разница:  [-0.05]
# Сеть сказала:  [3.16] , а верный ответ:  3.26 , разница:  [-0.1]
# Сеть сказала:  [2.97] , а верный ответ:  2.95 , разница:  [0.02]
# Сеть сказала:  [1.47] , а верный ответ:  1.42 , разница:  [0.04]
# Сеть сказала:  [3.53] , а верный ответ:  3.55 , разница:  [-0.02]
# Сеть сказала:  [2.82] , а верный ответ:  2.89 , разница:  [-0.06]
# Сеть сказала:  [3.28] , а верный ответ:  3.33 , разница:  [-0.05]
# Сеть сказала:  [2.59] , а верный ответ:  2.62 , разница:  [-0.03]
# Сеть сказала:  [4.38] , а верный ответ:  4.41 , разница:  [-0.04]
# Сеть сказала:  [2.82] , а верный ответ:  2.9 , разница:  [-0.08]
# Сеть сказала:  [3.55] , а верный ответ:  3.61 , разница:  [-0.06]
# Сеть сказала:  [2.2] , а верный ответ:  2.25 , разница:  [-0.05]
# Сеть сказала:  [4.24] , а верный ответ:  4.37 , разница:  [-0.13]
# Сеть сказала:  [4.6] , а верный ответ:  4.64 , разница:  [-0.04]
# Сеть сказала:  [3.58] , а верный ответ:  3.65 , разница:  [-0.07]
# Сеть сказала:  [3.16] , а верный ответ:  3.2 , разница:  [-0.04]
# Сеть сказала:  [2.52] , а верный ответ:  2.59 , разница:  [-0.06]
# Сеть сказала:  [2.44] , а верный ответ:  2.42 , разница:  [0.02]
# Сеть сказала:  [2.51] , а верный ответ:  2.53 , разница:  [-0.02]
# Сеть сказала:  [3.39] , а верный ответ:  3.39 , разница:  [-0.01]
# Сеть сказала:  [1.81] , а верный ответ:  1.8 , разница:  [0.]
# Сеть сказала:  [2.36] , а верный ответ:  2.39 , разница:  [-0.03]
# Сеть сказала:  [2.5] , а верный ответ:  2.56 , разница:  [-0.06]
# Сеть сказала:  [2.8] , а верный ответ:  2.78 , разница:  [0.03]

# %%
# Середина выборки
print(np.median(y_test))
# Out:
# 2.88985995396507

# %%
# Среднее
print(np.mean(y_test))
# Out:
# 2.92858393101213

# %%
import matplotlib.pyplot as plt
# Разброс предсказаний может показать перекос, если есть
plt.scatter(y_test, pred) 
plt.xlabel('Правильные значение')
plt.ylabel('Предсказания')
plt.axis('equal')
plt.xlim(plt.xlim())
plt.ylim(plt.ylim())
plt.plot([-100, 100], [-100, 100])
plt.show()
